# %%
#Dependencies

import pandas as pd
import requests
import matplotlib.pyplot as plt
import tweepy
import json
import numpy as np
from pprint import pprint
import datetime as dt
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer 
analyzer = SentimentIntensityAnalyzer()

# %%
# Twitter API Keys
consumer_key = "vbtDKBb6MLz1UDuXqjulinZWP"
consumer_secret = "porfKt9UTtSp2XRYfqT7W5CaLAsgTFgXAgsjFYaAyxc42asmnw"
access_token = "2503131714-U09cIrTKKguHgX4tLYxSIWFKqkpM3FCpko8huUm"
access_token_secret = "QT9zEyQXvVzObM46BrIsx9kgqnwmZmhUjtNhafPU3iGcB"

# Setup Tweepy API Authentication
auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_token_secret)
api = tweepy.API(auth, parser=tweepy.parsers.JSONParser())

# %%
results = []

# %%
users = api.search_users

# %%
twitter = api.search
for result in api.search("baby")['statuses']:
    pprint(result)
# Out:
# {'contributors': None,
#  'coordinates': None,
#  'created_at': 'Sat Nov 03 23:28:13 +0000 2018',
#  'entities': {'hashtags': [],
#               'symbols': [],
#               'urls': [{'display_url': 'twitter.com/i/web/status/1…',
#                         'expanded_url': 'https://twitter.com/i/web/status/1058863450292699138',
#                         'indices': [117, 140],
#                         'url': 'https://t.co/27vUhyEHOo'}],
#               'user_mentions': []},
#  'favorite_count': 0,
#  'favorited': False,
#  'geo': None,
#  'id': 1058863450292699138,
#  'id_str': '1058863450292699138',
#  'in_reply_to_screen_name': None,
#  'in_reply_to_status_id': None,
#  'in_reply_to_status_id_str': None,
#  'in_reply_to_user_id': None,
#  'in_reply_to_user_id_str': None,
#  'is_quote_status': False,
#  'lang': 'en',
#  'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#  'place': None,
#  'retweet_count': 0,
#  'retweeted': False,
# ...

# %%
tweet_df = pd.DataFrame(
    "name": result["user"]['name'],
    "user_id":result["user"]['id'],
    "sn": result["user"]["screen_name"],
    "id_num": result["id"],
    "id_str": result["id_str"],
    "status": result['text'],
    "desrption": result["user"]['description'],
    "location": result["user"]['location'],
    "favorites": result["favorite_count"],
    result["retweet_count"],
    result['user']["friends_count"],
    result["user"]["followers_count"],
    result["user"]["favourites_count"]
                       )
# Out:
# 993

# %%
result["id_str"]
# Out:
# '1058863444563255297'

# %%
result
# Out:
# {'contributors': None,
#  'coordinates': None,
#  'created_at': 'Sat Nov 03 23:28:12 +0000 2018',
#  'entities': {'hashtags': [],
#   'symbols': [],
#   'urls': [{'display_url': 'twitter.com/jessy0425_/sta…',
#     'expanded_url': 'https://twitter.com/jessy0425_/status/1056021120225341440',
#     'indices': [42, 65],
#     'url': 'https://t.co/8mgibqsc3T'}],
#   'user_mentions': [{'id': 1355783606,
#     'id_str': '1355783606',
#     'indices': [3, 11],
#     'name': 'drea',
#     'screen_name': '_dreavh'}]},
#  'favorite_count': 0,
#  'favorited': False,
#  'geo': None,
#  'id': 1058863444563255297,
#  'id_str': '1058863444563255297',
#  'in_reply_to_screen_name': None,
#  'in_reply_to_status_id': None,
#  'in_reply_to_status_id_str': None,
#  'in_reply_to_user_id': None,
#  'in_reply_to_user_id_str': None,
#  'is_quote_status': True,
#  'lang': 'en',
#  'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#  'place': None,
#  'possibly_sensitive': False,
# ...

# %%
wp = "39e6947a635f44f6ada6506c516085c7"
url = "https://proapi.whitepages.com/3.3/identity_check?"

params = {
    "api_key" : wp,
    "primary.name" : "Michael Diaz",
    "primary.address.city" : "Ledgewood",
    "primary.address.state_code" : "NJ",
    "primary.address.postal_code": "07852",
    "primary.address.street_line_1": "204 Drake Lane"
}
# query = url+"api_key="+wp+"primary.name"
response = requests.get(url, params=params)
response.json()
# Out:
# {'identity_check_score': 358,
#  'ip_address_checks': None,
#  'primary_address_checks': {'error': None,
#   'input_completeness': 'Complete',
#   'is_commercial': False,
#   'is_forwarder': False,
#   'is_valid': True,
#   'match_to_name': 'No match',
#   'resident': {'age_range': None, 'name': 'Rebecca Knowles'},
#   'type': 'Single unit',
#   'warnings': []},
#  'primary_email_address_checks': None,
#  'primary_phone_checks': None,
#  'request': {'api_key': '39e6947a635f44f6ada6506c516085c7',
#   'primary.address.city': 'Ledgewood',
#   'primary.address.postal_code': '07852',
#   'primary.address.state_code': 'NJ',
#   'primary.address.street_line_1': '204 Drake Lane',
#   'primary.name': 'Michael Diaz'},
#  'secondary_address_checks': None,
#  'secondary_email_address_checks': None,
#  'secondary_phone_checks': None}
